# %%
import pandas as pd
import altair as alt
import os 
from vega_datasets import data

# %%
cuisine_mapping = pd.read_csv('data/Cuisinne Mapping.csv')

# %%
# List files in data/Taste/
files = os.listdir('data/Taste/')
# Read in all files with pandas
# Filename as a column
dfs = []
for file in files:
    dfs.append(pd.read_csv('data/Taste/' + file))
    
# Concatenate all files
taste = pd.concat(dfs)

# %%
# Merge with cuisine mapping
mapping = taste.merge(cuisine_mapping, on='cuisine')
# Filter out those with blank "ISO 31661 Numeric"
mapping_filtered = mapping[mapping['ISO 31661 Numeric'].notnull()]
mapping_filtered.loc[:,'id'] = mapping_filtered['ISO 31661 Numeric'].astype(int).astype(str)
# Out:
# /home/johnymah/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:1743: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(ilocs[0], value)

# %%
mapping_filtered
# Out:
#        sweetness  saltiness  sourness  bitterness  savoriness  fattiness  \
# 170       100.00      44.25     97.58       38.63       22.14      44.58
# 171       100.00      48.26     10.31        2.98       29.82      53.99
# 172         8.56       3.64      0.00        0.00        0.00     100.00
# 173        98.80      60.79     10.53       27.40       33.21     100.00
# 174       100.00       3.65      0.00        0.00        0.00      43.50
# ...          ...        ...       ...         ...         ...        ...
# 11040     100.00      28.59     29.04       41.64       49.62      36.24
# 11041     100.00      26.38     48.94       26.21       10.80      55.32
# 11042      25.99     100.00     11.19       14.30       65.68      85.20
# 11043      22.20     100.00     15.77       22.69       69.06      61.42
# 11044      27.09     100.00     13.55       16.93       69.46      80.09
#
#        spiciness   id                               title     cuisine  \
# 170       8200.0  840                        Jack Burgers    American
# 171          0.0  840           Sweet Potato Lentil Chili    American
# 172     160000.0  840           Black Bean-Quinoa Burgers    American
# 173          0.0  840             Healthy Low Fat Burgers    American
# 174          0.0  840                 Dill Salmon Burgers    American
# ...          ...  ...                                 ...         ...
# 11040   375000.0  704           Fresh Shrimp Spring Rolls  Vietnamese
# 11041   375000.0  704  Quick Banh Mi {street food monday}  Vietnamese
# 11042        0.0  704      Vietnamese Grilled Squid Salad  Vietnamese
# 11043        0.0  704                   Breakfast Banh Mi  Vietnamese
# 11044        0.0  704               {spring} spring rolls  Vietnamese
#
#              Country  ISO 31661 Numeric Notes
# 170    United States              840.0   NaN
# 171    United States              840.0   NaN
# 172    United States              840.0   NaN
# 173    United States              840.0   NaN
# 174    United States              840.0   NaN
# ...              ...                ...   ...
# 11040       Viet Nam              704.0   NaN
# 11041       Viet Nam              704.0   NaN
# 11042       Viet Nam              704.0   NaN
# 11043       Viet Nam              704.0   NaN
# 11044       Viet Nam              704.0   NaN
#
# [6375 rows x 13 columns]

# %%
source = alt.topo_feature(data.world_110m.url, 'countries')
sphere = alt.sphere()
graticule = alt.graticule()

# flavors = mapping_filtered.columns[0:7]
# input_dropdown = alt.binding_select(options=flavors, name='Flavor')
# selection = alt.selection_single(fields=['Origin'], bind=input_dropdown)

flavor = 'sweetness'

# Layering and configuring the components
alt.Chart(source).mark_geoshape(
    stroke='black'
    ).encode(
        color= flavor + ':Q'
    ).transform_lookup(
    lookup='id',
    from_=alt.LookupData(mapping_filtered, 'id', [flavor])
).project(
    'naturalEarth1'
).properties(width=600, height=400).configure_view(stroke=None)
# Out:
# ---------------------------------------------------------------------------
# MaxRowsError                              Traceback (most recent call last)
# <ipython-input-6-f313fd5a1105> in <module>()
#      16     ).transform_lookup(
#      17     lookup='id',
# ---> 18     from_=alt.LookupData(mapping_filtered, 'id', [flavor])
#      19 ).project(
#      20     'naturalEarth1'
#
# ~/anaconda3/lib/python3.7/site-packages/altair/vegalite/v4/schema/core.py in __init__(self, data, key, fields, **kwds)
#    7631
#    7632     def __init__(self, data=Undefined, key=Undefined, fields=Undefined, **kwds):
# -> 7633         super(LookupData, self).__init__(data=data, key=key, fields=fields, **kwds)
#    7634
#    7635
#
# ~/anaconda3/lib/python3.7/site-packages/altair/utils/schemapi.py in __init__(self, *args, **kwds)
#     175
#     176         if DEBUG_MODE and self._class_is_valid_at_instantiation:
# --> 177             self.to_dict(validate=True)
#     178
#     179     def copy(self, deep=True, ignore=()):
#
# ~/anaconda3/lib/python3.7/site-packages/altair/vegalite/v4/api.py in to_dict(self, *args, **kwargs)
#     114         """Convert the chart to a dictionary suitable for JSON export."""
#     115         copy = self.copy(deep=False)
# --> 116         copy.data = _prepare_data(copy.data, kwargs.get("context"))
#     117         return super(LookupData, copy).to_dict(*args, **kwargs)
#     118
#
# ~/anaconda3/lib/python3.7/site-packages/altair/vegalite/v4/api.py in _prepare_data(data, context)
#      87     # convert dataframes  or objects with __geo_interface__ to dict
#      88     if isinstance(data, pd.DataFrame) or hasattr(data, "__geo_interface__"):
# ---> 89         data = _pipe(data, data_transformers.get())
#      90
#      91     # convert string input to a URLData
#
# ~/anaconda3/lib/python3.7/site-packages/toolz/functoolz.py in pipe(data, *funcs)
#     550     """
#     551     for func in funcs:
# --> 552         data = func(data)
#     553     return data
#     554
#
# ~/anaconda3/lib/python3.7/site-packages/toolz/functoolz.py in __call__(self, *args, **kwargs)
#     281     def __call__(self, *args, **kwargs):
#     282         try:
# --> 283             return self._partial(*args, **kwargs)
#     284         except TypeError as exc:
#     285             if self._should_curry(args, kwargs, exc):
#
# ~/anaconda3/lib/python3.7/site-packages/altair/vegalite/data.py in default_data_transformer(data, max_rows)
#      17 @curried.curry
#      18 def default_data_transformer(data, max_rows=5000):
# ---> 19     return curried.pipe(data, limit_rows(max_rows=max_rows), to_values)
#      20
#      21
#
# ~/anaconda3/lib/python3.7/site-packages/toolz/functoolz.py in pipe(data, *funcs)
#     550     """
#     551     for func in funcs:
# --> 552         data = func(data)
#     553     return data
#     554
#
# ~/anaconda3/lib/python3.7/site-packages/toolz/functoolz.py in __call__(self, *args, **kwargs)
#     281     def __call__(self, *args, **kwargs):
#     282         try:
# --> 283             return self._partial(*args, **kwargs)
#     284         except TypeError as exc:
#     285             if self._should_curry(args, kwargs, exc):
#
# ~/anaconda3/lib/python3.7/site-packages/altair/utils/data.py in limit_rows(data, max_rows)
#      82             "than the maximum allowed ({}). "
#      83             "For information on how to plot larger datasets "
# ---> 84             "in Altair, see the documentation".format(max_rows)
#      85         )
#      86     return data
#
# MaxRowsError: The number of rows in your dataset is greater than the maximum allowed (5000). For information on how to plot larger datasets in Altair, see the documentation

# %%
# Same as above, but with a filter for the flavor

# Keep first 8 columns of mapping_filtered
mapping_filtered_flavor = mapping_filtered[mapping_filtered.columns[0:8]]


mapping_filtered_flavor_pivoted = pd.melt(mapping_filtered_flavor, id_vars='id', value_vars=mapping_filtered_flavor.columns[1:8])
# Melt with 'id' as key
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-7-cdc12e552c29> in <module>()
#       5
#       6
# ----> 7 mapping_filtered_flavor_pivoted = pd.melt(mapping_filtered_flavor, id_vars='id', value_vars=mapping_filtered_flavor.columns[1:8])
#       8 # Melt with 'id' as key
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/melt.py in melt(frame, id_vars, value_vars, var_name, value_name, col_level, ignore_index)
#     134         mdata[col] = np.asanyarray(frame.columns._get_level_values(i)).repeat(N)
#     135
# --> 136     result = frame._constructor(mdata, columns=mcolumns)
#     137
#     138     if not ignore_index:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     466
#     467         elif isinstance(data, dict):
# --> 468             mgr = init_dict(data, index, columns, dtype=dtype)
#     469         elif isinstance(data, ma.MaskedArray):
#     470             import numpy.ma.mrecords as mrecords
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals/construction.py in init_dict(data, index, columns, dtype)
#     281             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     282         ]
# --> 283     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     284
#     285
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals/construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype, verify_integrity)
#      81
#      82         # don't force copy because getting jammed in an ndarray anyway
# ---> 83         arrays = _homogenize(arrays, index, dtype)
#      84
#      85         columns = ensure_index(columns)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals/construction.py in _homogenize(data, index, dtype)
#     350                 val = lib.fast_multiget(val, oindex._values, default=np.nan)
#     351             val = sanitize_array(
# --> 352                 val, index, dtype=dtype, copy=False, raise_cast_failure=False
#     353             )
#     354
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/construction.py in sanitize_array(data, index, dtype, copy, raise_cast_failure)
#     494     elif subarr.ndim > 1:
#     495         if isinstance(data, np.ndarray):
# --> 496             raise Exception("Data must be 1-dimensional")
#     497         else:
#     498             subarr = com.asarray_tuplesafe(data, dtype=dtype)
#
# Exception: Data must be 1-dimensional

# %%
# Take average of value by id, variabl
averaged = mapping_filtered_flavor_pivoted.groupby(['id','variable']).mean()
# Reset hierarchical index
averaged = averaged.reset_index()

# %%
averaged
# Out:
#      id    variable         value
# 0   156  bitterness  3.345268e+01
# 1   156   fattiness  6.659982e+01
# 2   156   saltiness  8.688942e+01
# 3   156  savoriness  5.350402e+01
# 4   156    sourness  2.619758e+01
# ..  ...         ...           ...
# 73  840   fattiness  6.700252e+01
# 74  840   saltiness  7.291652e+01
# 75  840  savoriness  4.397934e+01
# 76  840    sourness  4.188214e+01
# 77  840   spiciness  1.446679e+06
#
# [78 rows x 3 columns]

# %%
## NOT WORKING - needs debugged (only showing spiciness for some reason)
input_dropdown = alt.binding_select(options=list(mapping_filtered_flavor.columns[0:7]), name='Flavor')
selection = alt.selection_single(fields=['variable'], bind=input_dropdown)

# Create same map as above but with a filter for the flavor
# Layering and configuring the components
chart = alt.Chart(source).mark_geoshape(
    ).encode(
        color= 'value:Q',
        # opacity = 'variable:N'
    ).transform_lookup(
    lookup='id',
    from_=alt.LookupData(averaged, 'id', ['value','variable'])
).project(
    'equirectangular'
).properties(width=600, height=400
).add_selection(
    selection
).transform_filter(selection).facet(
    facet='variable:N',
    columns=2
)
chart
# Out:
# alt.FacetChart(...)

# %%
all_flavors = list(mapping_filtered_flavor.columns[0:7])
all_flavors
# Out:
# ['sweetness',
#  'saltiness',
#  'sourness',
#  'bitterness',
#  'savoriness',
#  'fattiness',
#  'spiciness']

# %%
charts = []
for selected_flavor in all_flavors:
    # filter source where variable == selected_flavor
    selected_averaged = averaged[averaged['variable'] == selected_flavor]

    chart = alt.Chart(source).mark_geoshape(
        ).encode(
            color= 'value:Q',
            # opacity = 'variable:N'
        ).transform_lookup(
        lookup='id',
        from_=alt.LookupData(selected_averaged, 'id', ['value','variable'])
    ).project(
        'equirectangular'
    ).properties(width=600, height=400, title= selected_flavor
    )
    charts.append(chart)
# Display a grid of charts
alt.vconcat((charts[1] | charts[2]),
(charts[3]| charts[4]),
(charts[5]| charts[6]),
).resolve_scale(
    color='independent'
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /workspaces/Recipe-Radar/Map.ipynb Cell 12 in <cell line: 2>()
#       <a href='vscode-notebook-cell://codespaces%2Bcodyburker-recipe-radar-4wp6jr67c64w/workspaces/Recipe-Radar/Map.ipynb#ch0000010vscode-remote?line=1'>2</a> for selected_flavor in all_flavors:
#       <a href='vscode-notebook-cell://codespaces%2Bcodyburker-recipe-radar-4wp6jr67c64w/workspaces/Recipe-Radar/Map.ipynb#ch0000010vscode-remote?line=2'>3</a>     # filter source where variable == selected_flavor
#       <a href='vscode-notebook-cell://codespaces%2Bcodyburker-recipe-radar-4wp6jr67c64w/workspaces/Recipe-Radar/Map.ipynb#ch0000010vscode-remote?line=3'>4</a>     selected_averaged = averaged[averaged['variable'] == selected_flavor]
#       <a href='vscode-notebook-cell://codespaces%2Bcodyburker-recipe-radar-4wp6jr67c64w/workspaces/Recipe-Radar/Map.ipynb#ch0000010vscode-remote?line=5'>6</a>     chart = alt.Chart(source).mark_geoshape(
#       <a href='vscode-notebook-cell://codespaces%2Bcodyburker-recipe-radar-4wp6jr67c64w/workspaces/Recipe-Radar/Map.ipynb#ch0000010vscode-remote?line=6'>7</a>         ).encode(
#       <a href='vscode-notebook-cell://codespaces%2Bcodyburker-recipe-radar-4wp6jr67c64w/workspaces/Recipe-Radar/Map.ipynb#ch0000010vscode-remote?line=7'>8</a>             color= 'value:Q',
#       <a href='vscode-notebook-cell://codespaces%2Bcodyburker-recipe-radar-4wp6jr67c64w/workspaces/Recipe-Radar/Map.ipynb#ch0000010vscode-remote?line=8'>9</a>             # opacity = 'variable:N'
#      <a href='vscode-notebook-cell://codespaces%2Bcodyburker-recipe-radar-4wp6jr67c64w/workspaces/Recipe-Radar/Map.ipynb#ch0000010vscode-remote?line=9'>10</a>         ).transform_lookup(
#      <a href='vscode-notebook-cell://codespaces%2Bcodyburker-recipe-radar-4wp6jr67c64w/workspaces/Recipe-Radar/Map.ipynb#ch0000010vscode-remote?line=10'>11</a>         lookup='id',
#      <a href='vscode-notebook-cell://codespaces%2Bcodyburker-recipe-radar-4wp6jr67c64w/workspaces/Recipe-Radar/Map.ipynb#ch0000010vscode-remote?line=11'>12</a>         from_=alt.LookupData(selected_averaged, 'id', ['value','variable'])
#      <a href='vscode-notebook-cell://codespaces%2Bcodyburker-recipe-radar-4wp6jr67c64w/workspaces/Recipe-Radar/Map.ipynb#ch0000010vscode-remote?line=12'>13</a>     ).project(
#      <a href='vscode-notebook-cell://codespaces%2Bcodyburker-recipe-radar-4wp6jr67c64w/workspaces/Recipe-Radar/Map.ipynb#ch0000010vscode-remote?line=13'>14</a>         'equirectangular'
#      <a href='vscode-notebook-cell://codespaces%2Bcodyburker-recipe-radar-4wp6jr67c64w/workspaces/Recipe-Radar/Map.ipynb#ch0000010vscode-remote?line=14'>15</a>     ).properties(width=600, height=400, title= selected_flavor
# ---> <a href='vscode-notebook-cell://codespaces%2Bcodyburker-recipe-radar-4wp6jr67c64w/workspaces/Recipe-Radar/Map.ipynb#ch0000010vscode-remote?line=15'>16</a>     ).tooltip(
#      <a href='vscode-notebook-cell://codespaces%2Bcodyburker-recipe-radar-4wp6jr67c64w/workspaces/Recipe-Radar/Map.ipynb#ch0000010vscode-remote?line=16'>17</a>         ['id', 'value', 'variable']
#      <a href='vscode-notebook-cell://codespaces%2Bcodyburker-recipe-radar-4wp6jr67c64w/workspaces/Recipe-Radar/Map.ipynb#ch0000010vscode-remote?line=17'>18</a>     )
#      <a href='vscode-notebook-cell://codespaces%2Bcodyburker-recipe-radar-4wp6jr67c64w/workspaces/Recipe-Radar/Map.ipynb#ch0000010vscode-remote?line=18'>19</a>     charts.append(chart)
#      <a href='vscode-notebook-cell://codespaces%2Bcodyburker-recipe-radar-4wp6jr67c64w/workspaces/Recipe-Radar/Map.ipynb#ch0000010vscode-remote?line=19'>20</a> # Display a grid of charts
#
# File /opt/python/3.10.4/lib/python3.10/site-packages/altair/utils/schemapi.py:258, in SchemaBase.__getattr__(self, attr)
#     256 except AttributeError:
#     257     _getattr = super(SchemaBase, self).__getattribute__
# --> 258 return _getattr(attr)
#
# AttributeError: 'Chart' object has no attribute 'tooltip'

# %%
chart = alt.vconcat((charts[1] | charts[2]).resolve_scale(color='independent'),
(charts[3]| charts[4]).resolve_scale(color='independent'),
(charts[5]| charts[6]).resolve_scale(color='independent'),
).resolve_scale(
    color='independent'
)
chart
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /workspaces/Recipe-Radar/Map.ipynb Cell 13 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://codespaces%2Bcodyburker-recipe-radar-4wp6jr67c64w/workspaces/Recipe-Radar/Map.ipynb#ch0000015vscode-remote?line=0'>1</a> chart = alt.vconcat((charts[1] | charts[2]).resolve_scale(color='independent'),
#       <a href='vscode-notebook-cell://codespaces%2Bcodyburker-recipe-radar-4wp6jr67c64w/workspaces/Recipe-Radar/Map.ipynb#ch0000015vscode-remote?line=1'>2</a> (charts[3]| charts[4]).resolve_scale(color='independent'),
#       <a href='vscode-notebook-cell://codespaces%2Bcodyburker-recipe-radar-4wp6jr67c64w/workspaces/Recipe-Radar/Map.ipynb#ch0000015vscode-remote?line=2'>3</a> (charts[5]| charts[6]).resolve_scale(color='independent'),
#       <a href='vscode-notebook-cell://codespaces%2Bcodyburker-recipe-radar-4wp6jr67c64w/workspaces/Recipe-Radar/Map.ipynb#ch0000015vscode-remote?line=3'>4</a> ).resolve_scale(
#       <a href='vscode-notebook-cell://codespaces%2Bcodyburker-recipe-radar-4wp6jr67c64w/workspaces/Recipe-Radar/Map.ipynb#ch0000015vscode-remote?line=4'>5</a>     color='independent'
#       <a href='vscode-notebook-cell://codespaces%2Bcodyburker-recipe-radar-4wp6jr67c64w/workspaces/Recipe-Radar/Map.ipynb#ch0000015vscode-remote?line=5'>6</a> )
#       <a href='vscode-notebook-cell://codespaces%2Bcodyburker-recipe-radar-4wp6jr67c64w/workspaces/Recipe-Radar/Map.ipynb#ch0000015vscode-remote?line=6'>7</a> chart
#
# IndexError: list index out of range

# %%
print(chart.to_json(indent=2))
# Out:
# {
#   "$schema": "https://vega.github.io/schema/vega-lite/v4.17.0.json",
#   "config": {
#     "view": {
#       "continuousHeight": 300,
#       "continuousWidth": 400
#     }
#   },
#   "data": {
#     "format": {
#       "feature": "countries",
#       "type": "topojson"
#     },
#     "url": "https://cdn.jsdelivr.net/npm/vega-datasets@v1.29.0/data/world-110m.json"
#   },
#   "datasets": {
#     "data-2b4aa875a2ec0b08a2c41982e31425f7": [
#       {
#         "id": "156",
#         "value": 804556.0192999999,
#         "variable": "spiciness"
#       },
#       {
#         "id": "250",
#         "value": 155906.4766,
#         "variable": "spiciness"
#       },
#       {
#         "id": "276",
#         "value": 200386.26668,
#         "variable": "spiciness"
#       },
#       {
#         "id": "356",
#         "value": 1105402.59668,
#         "variable": "spiciness"
#       },
#       {
#         "id": "372",
#         "value": 177171.12253999998,
#         "variable": "spiciness"
#       },
#       {
#         "id": "380",
#         "value": 80279.51329999999,
#         "variable": "spiciness"
#       },
#       {
#         "id": "408",
#         "value": 464799.99812,
#         "variable": "spiciness"
#       },
#       {
#         "id": "574",
#         "value": 122466.2,
#         "variable": "spiciness"
#       },
#       {
#         "id": "704",
#         "value": 908771.3304,
#         "variable": "spiciness"
#       },
#       {
#         "id": "724",
#         "value": 420440.48312,
#         "variable": "spiciness"
#       },
#       {
#         "id": "764",
#         "value": 891569.4789199999,
#         "variable": "spiciness"
#       },
#       {
#         "id": "826",
#         "value": 60653.684799999995,
#         "variable": "spiciness"
#       },
#       {
#         "id": "840",
#         "value": 1446679.4525,
#         "variable": "spiciness"
#       }
#     ],
#     "data-66f778f48b9f29aab6e9aebb7dca3bdf": [
#       {
#         "id": "156",
#         "value": 86.88942,
#         "variable": "saltiness"
#       },
#       {
#         "id": "250",
#         "value": 88.0746,
#         "variable": "saltiness"
#       },
#       {
#         "id": "276",
#         "value": 72.0325,
#         "variable": "saltiness"
#       },
#       {
#         "id": "356",
#         "value": 67.23978,
#         "variable": "saltiness"
#       },
#       {
#         "id": "372",
#         "value": 92.78094,
#         "variable": "saltiness"
#       },
#       {
#         "id": "380",
#         "value": 79.04408000000001,
#         "variable": "saltiness"
#       },
#       {
#         "id": "408",
#         "value": 86.99574000000001,
#         "variable": "saltiness"
#       },
#       {
#         "id": "574",
#         "value": 69.79938666666666,
#         "variable": "saltiness"
#       },
#       {
#         "id": "704",
#         "value": 75.73125999999999,
#         "variable": "saltiness"
#       },
#       {
#         "id": "724",
#         "value": 79.02232000000001,
#         "variable": "saltiness"
#       },
#       {
#         "id": "764",
#         "value": 75.332,
#         "variable": "saltiness"
#       },
#       {
#         "id": "826",
#         "value": 44.98818,
#         "variable": "saltiness"
#       },
#       {
#         "id": "840",
#         "value": 72.91652,
#         "variable": "saltiness"
#       }
#     ],
#     "data-c85906e8a7db2f00d7e77ef88b1d95f4": [
#       {
#         "id": "156",
#         "value": 53.50402,
#         "variable": "savoriness"
#       },
#       {
#         "id": "250",
#         "value": 44.65616000000001,
#         "variable": "savoriness"
#       },
#       {
#         "id": "276",
#         "value": 38.9507,
#         "variable": "savoriness"
#       },
#       {
#         "id": "356",
#         "value": 35.570620000000005,
#         "variable": "savoriness"
#       },
#       {
#         "id": "372",
#         "value": 39.88704,
#         "variable": "savoriness"
#       },
#       {
#         "id": "380",
#         "value": 47.009519999999995,
#         "variable": "savoriness"
#       },
#       {
#         "id": "408",
#         "value": 50.21172,
#         "variable": "savoriness"
#       },
#       {
#         "id": "574",
#         "value": 40.346293333333335,
#         "variable": "savoriness"
#       },
#       {
#         "id": "704",
#         "value": 49.84762,
#         "variable": "savoriness"
#       },
#       {
#         "id": "724",
#         "value": 46.204159999999995,
#         "variable": "savoriness"
#       },
#       {
#         "id": "764",
#         "value": 49.13112,
#         "variable": "savoriness"
#       },
#       {
#         "id": "826",
#         "value": 23.229080000000003,
#         "variable": "savoriness"
#       },
#       {
#         "id": "840",
#         "value": 43.97934,
#         "variable": "savoriness"
#       }
#     ],
#     "data-d793fb7fb2f04c3ff75db17e0d9a7370": [
#       {
#         "id": "156",
#         "value": 66.59982000000001,
#         "variable": "fattiness"
#       },
#       {
#         "id": "250",
#         "value": 70.55514,
#         "variable": "fattiness"
#       },
#       {
#         "id": "276",
#         "value": 66.35832,
#         "variable": "fattiness"
#       },
#       {
#         "id": "356",
#         "value": 64.54451999999999,
#         "variable": "fattiness"
#       },
#       {
#         "id": "372",
#         "value": 63.2813,
#         "variable": "fattiness"
#       },
#       {
#         "id": "380",
#         "value": 69.04536,
#         "variable": "fattiness"
#       },
#       {
#         "id": "408",
#         "value": 61.87504,
#         "variable": "fattiness"
#       },
#       {
#         "id": "574",
#         "value": 66.6048,
#         "variable": "fattiness"
#       },
#       {
#         "id": "704",
#         "value": 62.05442,
#         "variable": "fattiness"
#       },
#       {
#         "id": "724",
#         "value": 70.90368,
#         "variable": "fattiness"
#       },
#       {
#         "id": "764",
#         "value": 70.16374,
#         "variable": "fattiness"
#       },
#       {
#         "id": "826",
#         "value": 74.42786,
#         "variable": "fattiness"
#       },
#       {
#         "id": "840",
#         "value": 67.00252,
#         "variable": "fattiness"
#       }
#     ],
#     "data-f13eb4ca5ce92e1930779d03d53d6172": [
#       {
#         "id": "156",
#         "value": 26.19758,
#         "variable": "sourness"
#       },
#       {
#         "id": "250",
#         "value": 34.860459999999996,
#         "variable": "sourness"
#       },
#       {
#         "id": "276",
#         "value": 22.0989,
#         "variable": "sourness"
#       },
#       {
#         "id": "356",
#         "value": 41.45544,
#         "variable": "sourness"
#       },
#       {
#         "id": "372",
#         "value": 21.90748,
#         "variable": "sourness"
#       },
#       {
#         "id": "380",
#         "value": 48.01788,
#         "variable": "sourness"
#       },
#       {
#         "id": "408",
#         "value": 24.28782,
#         "variable": "sourness"
#       },
#       {
#         "id": "574",
#         "value": 20.554399999999998,
#         "variable": "sourness"
#       },
#       {
#         "id": "704",
#         "value": 25.563779999999998,
#         "variable": "sourness"
#       },
#       {
#         "id": "724",
#         "value": 42.518080000000005,
#         "variable": "sourness"
#       },
#       {
#         "id": "764",
#         "value": 28.381580000000003,
#         "variable": "sourness"
#       },
#       {
#         "id": "826",
#         "value": 23.40234,
#         "variable": "sourness"
#       },
#       {
#         "id": "840",
#         "value": 41.88214,
#         "variable": "sourness"
#       }
#     ],
#     "data-f1ed730c474699520903ebbff0740f3b": [
#       {
#         "id": "156",
#         "value": 33.45268,
#         "variable": "bitterness"
#       },
#       {
#         "id": "250",
#         "value": 31.1674,
#         "variable": "bitterness"
#       },
#       {
#         "id": "276",
#         "value": 20.779259999999997,
#         "variable": "bitterness"
#       },
#       {
#         "id": "356",
#         "value": 34.4617,
#         "variable": "bitterness"
#       },
#       {
#         "id": "372",
#         "value": 28.06412,
#         "variable": "bitterness"
#       },
#       {
#         "id": "380",
#         "value": 36.1563,
#         "variable": "bitterness"
#       },
#       {
#         "id": "408",
#         "value": 28.5075,
#         "variable": "bitterness"
#       },
#       {
#         "id": "574",
#         "value": 19.011973333333334,
#         "variable": "bitterness"
#       },
#       {
#         "id": "704",
#         "value": 34.67208,
#         "variable": "bitterness"
#       },
#       {
#         "id": "724",
#         "value": 29.9435,
#         "variable": "bitterness"
#       },
#       {
#         "id": "764",
#         "value": 31.99724,
#         "variable": "bitterness"
#       },
#       {
#         "id": "826",
#         "value": 17.1313,
#         "variable": "bitterness"
#       },
#       {
#         "id": "840",
#         "value": 30.36104,
#         "variable": "bitterness"
#       }
#     ]
#   },
#   "resolve": {
#     "scale": {
#       "color": "independent"
#     }
#   },
#   "vconcat": [
#     {
#       "hconcat": [
#         {
#           "encoding": {
#             "color": {
#               "field": "value",
#               "type": "quantitative"
#             }
#           },
#           "height": 400,
#           "mark": "geoshape",
#           "projection": {
#             "type": "equirectangular"
#           },
#           "title": "saltiness",
#           "transform": [
#             {
#               "from": {
#                 "data": {
#                   "name": "data-66f778f48b9f29aab6e9aebb7dca3bdf"
#                 },
#                 "fields": [
#                   "value",
#                   "variable"
#                 ],
#                 "key": "id"
#               },
#               "lookup": "id"
#             }
#           ],
#           "width": 600
#         },
#         {
#           "encoding": {
#             "color": {
#               "field": "value",
#               "type": "quantitative"
#             }
#           },
#           "height": 400,
#           "mark": "geoshape",
#           "projection": {
#             "type": "equirectangular"
#           },
#           "title": "sourness",
#           "transform": [
#             {
#               "from": {
#                 "data": {
#                   "name": "data-f13eb4ca5ce92e1930779d03d53d6172"
#                 },
#                 "fields": [
#                   "value",
#                   "variable"
#                 ],
#                 "key": "id"
#               },
#               "lookup": "id"
#             }
#           ],
#           "width": 600
#         }
#       ],
#       "resolve": {
#         "scale": {
#           "color": "independent"
#         }
#       }
#     },
#     {
#       "hconcat": [
#         {
#           "encoding": {
#             "color": {
#               "field": "value",
#               "type": "quantitative"
#             }
#           },
#           "height": 400,
#           "mark": "geoshape",
#           "projection": {
#             "type": "equirectangular"
#           },
#           "title": "bitterness",
#           "transform": [
#             {
#               "from": {
#                 "data": {
#                   "name": "data-f1ed730c474699520903ebbff0740f3b"
#                 },
#                 "fields": [
#                   "value",
#                   "variable"
#                 ],
#                 "key": "id"
#               },
#               "lookup": "id"
#             }
#           ],
#           "width": 600
#         },
#         {
#           "encoding": {
#             "color": {
#               "field": "value",
#               "type": "quantitative"
#             }
#           },
#           "height": 400,
#           "mark": "geoshape",
#           "projection": {
#             "type": "equirectangular"
#           },
#           "title": "savoriness",
#           "transform": [
#             {
#               "from": {
#                 "data": {
#                   "name": "data-c85906e8a7db2f00d7e77ef88b1d95f4"
#                 },
#                 "fields": [
#                   "value",
#                   "variable"
#                 ],
#                 "key": "id"
#               },
#               "lookup": "id"
#             }
#           ],
#           "width": 600
#         }
#       ],
#       "resolve": {
#         "scale": {
#           "color": "independent"
#         }
#       }
#     },
#     {
#       "hconcat": [
#         {
#           "encoding": {
#             "color": {
#               "field": "value",
#               "type": "quantitative"
#             }
#           },
#           "height": 400,
#           "mark": "geoshape",
#           "projection": {
#             "type": "equirectangular"
#           },
#           "title": "fattiness",
#           "transform": [
#             {
#               "from": {
#                 "data": {
#                   "name": "data-d793fb7fb2f04c3ff75db17e0d9a7370"
#                 },
#                 "fields": [
#                   "value",
#                   "variable"
#                 ],
#                 "key": "id"
#               },
#               "lookup": "id"
#             }
#           ],
#           "width": 600
#         },
#         {
#           "encoding": {
#             "color": {
#               "field": "value",
#               "type": "quantitative"
#             }
#           },
#           "height": 400,
#           "mark": "geoshape",
#           "projection": {
#             "type": "equirectangular"
#           },
#           "title": "spiciness",
#           "transform": [
#             {
#               "from": {
#                 "data": {
#                   "name": "data-2b4aa875a2ec0b08a2c41982e31425f7"
#                 },
#                 "fields": [
#                   "value",
#                   "variable"
#                 ],
#                 "key": "id"
#               },
#               "lookup": "id"
#             }
#           ],
#           "width": 600
#         }
#       ],
#       "resolve": {
#         "scale": {
#           "color": "independent"
#         }
#       }
#     }
#   ]
# }
