# %% [markdown]
# # Food Data Exploration for Data Visualization

# %% [markdown]
# ## Notes
#
# https://spoonacular.com/food-api/docs
#
# Using Rapid API

# %% [markdown]
# ## Installs

# %%
# !pip install pandasql --quiet
# Out:
#   Building wheel for pandasql (setup.py) ... done

# %% [markdown]
# ## Imports

# %%
# Imports
from google.colab import drive
import altair as alt
import pandas as pd
import numpy as np
import pandasql
import requests
import json
import ast
import os
import re

# %% [markdown]
# ## Parameters

# %%
drive.mount('/content/drive')
#drive.flush_and_unmount()
# Out:
# Mounted at /content/drive

# %%
Key_Name = 'Robert'
with open('/content/drive/MyDrive/w209/Final/Keys/' + Key_Name, 'r') as f:
    Key = f.read()

# %%
Host = 'spoonacular-recipe-food-nutrition-v1.p.rapidapi.com'

# %% [markdown]
# # Get Recipes

# %% [markdown]
# ##### Load Data

# %%
Ingredients = pd.DataFrame()
path = '/content/drive/MyDrive/w209/Final/Data/Ingredients/'
for file in os.listdir(path):
  data = pd.read_csv(path+file)
  data.drop_duplicates(subset=['id'], inplace=True)
  Ingredients = pd.concat([Ingredients, data])

Ingredients
# Out:
#                                            ingredients       id  \
# 0    [{'name': 'trimmed baby bok choy', 'image': 'b...   838297
# 1    [{'name': 'chicken breast', 'image': 'chicken-...   608519
# 2    [{'name': 'cooked broccoli', 'image': 'broccol...   127730
# 3    [{'name': 'broccoli florets', 'image': 'brocco...  1031836
# 4    [{'name': 'brown sugar', 'image': 'light-brown...   112942
# ..                                                 ...      ...
# 495  [{'name': 'all purpose flour', 'image': 'flour...   328195
# 496  [{'name': 'cajun seasoning', 'image': 'chili-p...   542568
# 497  [{'name': 'bell pepper', 'image': 'bell-pepper...   316384
# 498  [{'name': 'butter', 'image': 'butter-sliced.jp...    34805
# 499  [{'name': 'fresh baby spinach', 'image': 'spin...   244288
#
#                                                  title  cuisine
# 0                                   Chicken Fried Rice  Chinese
# 1                       Kung Pao Chicken Lettuce Wraps  Chinese
# 2    Sweet and Spicy Chinese Five Spice Roasted Alm...  Chinese
# 3        Quinoa Fried Rice with Chicken and Vegetables  Chinese
# 4                  Spicy Chinese Chicken (Slow Cooker)  Chinese
# ..                                                 ...      ...
# 495                               Chicken Jambalaya II    Cajun
# 496                  Cajun Shrimp and Quinoa Casserole    Cajun
# 497                                    Vegetable Gumbo    Cajun
# 498                            Half-hour Chicken Gumbo    Cajun
# 499                                 Cajun Cabbage Stew    Cajun
#
# [4170 rows x 4 columns]

# %%
ingredients = pd.DataFrame()
failed = []
for i in Ingredients.iterrows():
  data = i[1]['ingredients'].replace("'", "\"").replace("None", "\"None\"")
  try:
    data = json.loads(data)
    data = pd.json_normalize(data)
  except:
    failed.append(i[1]['id']) # Has issues with mixed ' and " as with contractions ([A-Za-z]+)[\'`]([A-Za-z]+) or possessives ([A-Za-z]+)[\'`](\s+)
    continue
  data['id'] = i[1]['id']
  data['title'] = i[1]['title']
  data['cuisine'] = i[1]['cuisine']
  data = data[['id', 'title', 'cuisine', 'name', 'amount.metric.value', 'amount.metric.unit', 'amount.us.value', 'amount.us.unit']]
  ingredients = pd.concat([ingredients, data])
ingredients
# Out:
#         id               title  cuisine                          name  \
# 0   838297  Chicken Fried Rice  Chinese         trimmed baby bok choy
# 1   838297  Chicken Fried Rice  Chinese                  black pepper
# 2   838297  Chicken Fried Rice  Chinese  lean boneless chicken breast
# 3   838297  Chicken Fried Rice  Chinese                 chicken broth
# 4   838297  Chicken Fried Rice  Chinese                    cornstarch
# ..     ...                 ...      ...                           ...
# 2   244288  Cajun Cabbage Stew    Cajun                corn bread mix
# 3   244288  Cajun Cabbage Stew    Cajun                           egg
# 4   244288  Cajun Cabbage Stew    Cajun                      jalapeno
# 5   244288  Cajun Cabbage Stew    Cajun   cooked frozen shredded meat
# 6   244288  Cajun Cabbage Stew    Cajun                          milk
#
#     amount.metric.value amount.metric.unit  amount.us.value amount.us.unit
# 0               709.764                  g         3.000000           cups
# 1                 0.125               tsps         0.125000           tsps
# 2               453.592                  g         1.000000          pound
# 3                58.750                 ml         0.250000            cup
# 4                 1.000                tsp         1.000000            tsp
# ..                  ...                ...              ...            ...
# 2               226.796                  g         8.000000         ounces
# 3                 1.000                            1.000000
# 4                48.000              slice        48.000000          slice
# 5               340.194                  g        12.000000         ounces
# 6                81.333                 ml         0.333333            cup
#
# [50242 rows x 8 columns]

# %%
path = '/content/drive/MyDrive/w209/Final/Data/Flattened/ingredients.csv'
ingredients.to_csv(path, mode='w')

# %%
Nutrition = pd.DataFrame()
path = '/content/drive/MyDrive/w209/Final/Data/Nutrition/'
for file in os.listdir(path):
  data = pd.read_csv(path+file)
  data.drop_duplicates(subset=['id'], inplace=True)
  Nutrition = pd.concat([Nutrition, data])

Nutrition
# Out:
#                                           badNutrition  \
# 0    [{'title': 'Calories', 'amount': '556k', 'inde...
# 1    [{'title': 'Calories', 'amount': '304k', 'inde...
# 2    [{'title': 'Calories', 'amount': '388k', 'inde...
# 3    [{'title': 'Calories', 'amount': '304k', 'inde...
# 4    [{'title': 'Calories', 'amount': '414k', 'inde...
# ..                                                 ...
# 495  [{'title': 'Calories', 'amount': '528k', 'inde...
# 496  [{'title': 'Calories', 'amount': '481k', 'inde...
# 497  [{'title': 'Calories', 'amount': '680k', 'inde...
# 498  [{'title': 'Calories', 'amount': '587k', 'inde...
# 499  [{'title': 'Calories', 'amount': '72k', 'inden...
#
#                                          goodNutrition       id  \
# 0    [{'title': 'Protein', 'amount': '12g', 'indent...   580502
# 1    [{'title': 'Protein', 'amount': '27g', 'indent...  1175851
# 2    [{'title': 'Protein', 'amount': '39g', 'indent...  1178513
# 3    [{'title': 'Protein', 'amount': '30g', 'indent...   274003
# 4    [{'title': 'Protein', 'amount': '28g', 'indent...   709884
# ..                                                 ...      ...
# 495  [{'title': 'Protein', 'amount': '47g', 'indent...   328195
# 496  [{'title': 'Protein', 'amount': '40g', 'indent...   542568
# 497  [{'title': 'Protein', 'amount': '33g', 'indent...   316384
# 498  [{'title': 'Protein', 'amount': '29g', 'indent...    34805
# 499  [{'title': 'Protein', 'amount': '3g', 'indente...   244288
#
#                                    title    cuisine
# 0               Caribbean Easter Egg Dye  Caribbean
# 1           Caribbean Rum Punch Cocktail  Caribbean
# 2    McDonald’s Shamrock Shake – Copycat  Caribbean
# 3               Peppermint-Mocha Delight  Caribbean
# 4                  Caribbean Truffle Pie  Caribbean
# ..                                   ...        ...
# 495                 Chicken Jambalaya II      Cajun
# 496    Cajun Shrimp and Quinoa Casserole      Cajun
# 497                      Vegetable Gumbo      Cajun
# 498              Half-hour Chicken Gumbo      Cajun
# 499                   Cajun Cabbage Stew      Cajun
#
# [4170 rows x 5 columns]

# %%
nutrition = pd.DataFrame()
failed = []
for n in Nutrition.iterrows():
  data = n[1]['badNutrition'].replace("'", "\"").replace("True", "\"True\"").replace("False", "\"False\"").replace("None", "\"None\"")
  try:
    data = json.loads(data)
    data = pd.json_normalize(data)
  except:
    failed.append(n[1]['id']) # Has issues with mixed ' and " as with contractions ([A-Za-z]+)[\'`]([A-Za-z]+) or possessives ([A-Za-z]+)[\'`](\s+)
    continue
  data['id'] = n[1]['id']
  data['name'] = n[1]['title']
  data['cuisine'] = n[1]['cuisine']
  data = data[['id', 'cuisine', 'name', 'title', 'amount', 'indented', 'percentOfDailyNeeds']]
  nutrition = pd.concat([nutrition, data])
  
nutrition
# Out:
#         id    cuisine                      name          title amount  \
# 0   580502  Caribbean  Caribbean Easter Egg Dye       Calories   556k
# 1   580502  Caribbean  Caribbean Easter Egg Dye            Fat    29g
# 2   580502  Caribbean  Caribbean Easter Egg Dye  Saturated Fat     4g
# 3   580502  Caribbean  Caribbean Easter Egg Dye  Carbohydrates    65g
# 4   580502  Caribbean  Caribbean Easter Egg Dye          Sugar     5g
# ..     ...        ...                       ...            ...    ...
# 2   244288      Cajun        Cajun Cabbage Stew  Saturated Fat   0.4g
# 3   244288      Cajun        Cajun Cabbage Stew  Carbohydrates    12g
# 4   244288      Cajun        Cajun Cabbage Stew          Sugar     6g
# 5   244288      Cajun        Cajun Cabbage Stew    Cholesterol    8mg
# 6   244288      Cajun        Cajun Cabbage Stew         Sodium   57mg
#
#    indented  percentOfDailyNeeds
# 0     False                27.84
# 1     False                44.62
# 2      True                25.37
# 3     False                21.68
# 4      True                 5.98
# ..      ...                  ...
# 2      True                 2.51
# 3     False                 4.25
# 4      True                 7.56
# 5     False                 2.75
# 6     False                 2.49
#
# [29758 rows x 7 columns]

# %%
path = '/content/drive/MyDrive/w209/Final/Data/Flattened/nutrition.csv'
nutrition.to_csv(path, mode='w')

# %%
taste = pd.DataFrame()
path = '/content/drive/MyDrive/w209/Final/Data/Taste/'
for file in os.listdir(path):
  data = pd.read_csv(path+file)
  data.drop_duplicates(subset=['id'], inplace=True)  
  data = data[['id', 'cuisine', 'title', 'sweetness', 'saltiness', 'sourness', 'bitterness', 'savoriness', 'fattiness', 'spiciness']]
  taste = pd.concat([taste, data])

taste
# Out:
#          id   cuisine                                              title  \
# 0    473895  European                Rigatoni Brussel Sprout Bake + Figs
# 1    204988  European  Parting Glass Belgian Dubbel (For Intermediate...
# 2    758105  European  Late Summer Minestrone with Butternut Squash a...
# 3    603272  European                            Greek Salad Quinoa Bowl
# 4    491863  European                      Green Goddess Pasta Primavera
# ..      ...       ...                                                ...
# 495  328195     Cajun                               Chicken Jambalaya II
# 496  542568     Cajun                  Cajun Shrimp and Quinoa Casserole
# 497  316384     Cajun                                    Vegetable Gumbo
# 498   34805     Cajun                            Half-hour Chicken Gumbo
# 499  244288     Cajun                                 Cajun Cabbage Stew
#
#      sweetness  saltiness  sourness  bitterness  savoriness  fattiness  \
# 0       100.00      16.06     34.38       14.20       10.75      65.81
# 1        47.48     100.00     27.89       26.62       37.55      54.74
# 2        80.16      91.51     94.27      100.00       85.02      83.32
# 3        31.41      15.69     36.00       25.57        2.50     100.00
# 4        70.37      34.30    100.00       25.42       23.32      58.79
# ..         ...        ...       ...         ...         ...        ...
# 495      54.60     100.00     35.61       27.20       49.16      66.34
# 496      22.83     100.00     13.39       16.57       70.14      64.23
# 497      31.68     100.00     17.23       29.38       52.58      65.06
# 498      33.88      98.51     39.61       25.99       59.44     100.00
# 499     100.00       8.88      2.17        1.31        5.37      25.12
#
#       spiciness
# 0     1800000.0
# 1           0.0
# 2           0.0
# 3       10000.0
# 4           0.0
# ..          ...
# 495     79450.0
# 496         0.0
# 497      5950.0
# 498     15100.0
# 499  24454410.0
#
# [4170 rows x 10 columns]

# %%
path = '/content/drive/MyDrive/w209/Final/Data/Flattened/taste.csv'
taste.to_csv(path, mode='w')

# %%
# From here we can shape the flattened data to flow directly into data visuals
pandasql.sqldf("""
    SELECT *
      FROM ingredients
      LIMIT 10
""")
# Out:
#        id               title  cuisine                          name  \
# 0  838297  Chicken Fried Rice  Chinese         trimmed baby bok choy
# 1  838297  Chicken Fried Rice  Chinese                  black pepper
# 2  838297  Chicken Fried Rice  Chinese  lean boneless chicken breast
# 3  838297  Chicken Fried Rice  Chinese                 chicken broth
# 4  838297  Chicken Fried Rice  Chinese                    cornstarch
# 5  838297  Chicken Fried Rice  Chinese                  fresh ginger
# 6  838297  Chicken Fried Rice  Chinese                 grapeseed oil
# 7  838297  Chicken Fried Rice  Chinese               fresh mushrooms
# 8  838297  Chicken Fried Rice  Chinese                         onion
# 9  838297  Chicken Fried Rice  Chinese                  oyster sauce
#
#    amount.metric.value amount.metric.unit  amount.us.value amount.us.unit
# 0              709.764                  g            3.000           cups
# 1                0.125               tsps            0.125           tsps
# 2              453.592                  g            1.000          pound
# 3               58.750                 ml            0.250            cup
# 4                1.000                tsp            1.000            tsp
# 5                2.000               tsps            2.000           tsps
# 6                2.000              Tbsps            2.000          Tbsps
# 7                8.000                               8.000
# 8                1.000                               1.000
# 9                2.000              Tbsps            2.000          Tbsps
