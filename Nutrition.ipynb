# %%
# !pip install vega_datasets
# Out:
# Requirement already satisfied: vega_datasets in c:\users\msuryana\anaconda3\lib\site-packages (0.9.0)
# Requirement already satisfied: pandas in c:\users\msuryana\anaconda3\lib\site-packages (from vega_datasets) (1.2.4)
# Requirement already satisfied: pytz>=2017.3 in c:\users\msuryana\anaconda3\lib\site-packages (from pandas->vega_datasets) (2021.1)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\msuryana\anaconda3\lib\site-packages (from pandas->vega_datasets) (1.20.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\msuryana\anaconda3\lib\site-packages (from pandas->vega_datasets) (2.8.1)
# Requirement already satisfied: six>=1.5 in c:\users\msuryana\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas->vega_datasets) (1.12.0)

# %%
import pandas as pd
import altair as alt
import os 
from vega_datasets import data

# %%
# List files in data/Taste/
files = os.listdir('data/Taste/')
# Read in all files with pandas
# Filename as a column
dfs = []
for file in files:
    dfs.append(pd.read_csv('data/Taste/' + file))
    
# Concatenate all files
taste = pd.concat(dfs)
taste
# Out:
#      sweetness  saltiness  sourness  bitterness  savoriness  fattiness  \
# 0        34.20     100.00     36.03       24.14       48.96      60.28
# 1        88.34      96.81    100.00       88.04       38.84      33.89
# 2        33.02     100.00     22.62       33.36       79.68      61.05
# 3        20.08     100.00     23.24       18.63       66.20      62.56
# 4       100.00      65.23     99.22       49.19       52.86      58.83
# ..         ...        ...       ...         ...         ...        ...
# 495     100.00      14.41      3.44        8.74       10.62      91.17
# 496      19.21      87.47     19.36       15.22       42.11     100.00
# 497     100.00      66.47     35.33       26.69       61.59      96.59
# 498      79.55      10.68     36.44       49.79       16.66     100.00
# 499      99.90      51.96     36.11       24.23       33.23     100.00
#
#      spiciness      id                                              title  \
# 0          0.0  759983                  Tortilla Lasagna with Swiss Chard
# 1          0.0  631051  Avocado, Mozzarella and Bruschetta Chicken - I...
# 2      14900.0  612345       {One Dish} Quinoa Chicken Parmesan Casserole
# 3      14900.0  955390          Zucchini & Sweet Potato Noodle Minestrone
# 4          0.0  347822                                    Pasta Primavera
# ..         ...     ...                                                ...
# 495        0.0  552689                   Walnut-Rosemary Olive Oil Scones
# 496        0.0  585934                    Fish and Chips with Beer Batter
# 497        0.0  603889                             Alaskan fish and chips
# 498        0.0  493798                                Easy Cheddar Scones
# 499        0.0   85931                      Low Fat Crispy Fish and Chips
#
#      cuisine
# 0    Italian
# 1    Italian
# 2    Italian
# 3    Italian
# 4    Italian
# ..       ...
# 495  British
# 496  British
# 497  British
# 498  British
# 499  British
#
# [11045 rows x 10 columns]

# %%
# List files in data/Nutrition/
files = os.listdir('data/Nutrition/')
# Read in all files with pandas
# Filename as a column

nutrition = pd.DataFrame()
for file in files:
    nutrition = pd.concat([nutrition,pd.read_csv('data/Nutrition/' + file)], axis=0)
    
# Concatenate all files
nutrition
# Out:
#                                           badNutrition  \
# 0    [{'title': 'Calories', 'amount': '720k', 'inde...
# 1    [{'title': 'Calories', 'amount': '487k', 'inde...
# 2    [{'title': 'Calories', 'amount': '752k', 'inde...
# 3    [{'title': 'Calories', 'amount': '168k', 'inde...
# 4    [{'title': 'Calories', 'amount': '375k', 'inde...
# ..                                                 ...
# 495  [{'title': 'Calories', 'amount': '349k', 'inde...
# 496  [{'title': 'Calories', 'amount': '422k', 'inde...
# 497  [{'title': 'Calories', 'amount': '1112k', 'ind...
# 498  [{'title': 'Calories', 'amount': '482k', 'inde...
# 499  [{'title': 'Calories', 'amount': '485k', 'inde...
#
#                                          goodNutrition      id  \
# 0    [{'title': 'Protein', 'amount': '35g', 'indent...  314135
# 1    [{'title': 'Protein', 'amount': '39g', 'indent...  715038
# 2    [{'title': 'Protein', 'amount': '29g', 'indent...  653275
# 3    [{'title': 'Protein', 'amount': '5g', 'indente...   47119
# 4    [{'title': 'Protein', 'amount': '13g', 'indent...  122714
# ..                                                 ...     ...
# 495  [{'title': 'Protein', 'amount': '8g', 'indente...  520285
# 496  [{'title': 'Protein', 'amount': '18g', 'indent...  611974
# 497  [{'title': 'Protein', 'amount': '27g', 'indent...  755718
# 498  [{'title': 'Protein', 'amount': '37g', 'indent...  201020
# 499  [{'title': 'Protein', 'amount': '35g', 'indent...  577571
#
#                                                  title     cuisine
# 0      North African Inspired Rub for Fish and Chicken     African
# 1    Harissa Shakshuka (North African Eggs in Purga...     African
# 2                          North African Chickpea Soup     African
# 3                             South African Beef Curry     African
# 4                    West African Tropical Fruit Salad     African
# ..                                                 ...         ...
# 495                          Fresh Shrimp Spring Rolls  Vietnamese
# 496                 Quick Banh Mi {street food monday}  Vietnamese
# 497                     Vietnamese Grilled Squid Salad  Vietnamese
# 498                                  Breakfast Banh Mi  Vietnamese
# 499                              {spring} spring rolls  Vietnamese
#
# [11045 rows x 5 columns]

# %%
pd.options.display.width = 0
pd.set_option('display.max_colwidth',-1)
nutrition[nutrition['id']==580502]['badNutrition']
# Out:
# <ipython-input-52-0bfaf841ef47>:2: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('display.max_colwidth',-1)
# 0    [{'title': 'Calories', 'amount': '556k', 'indented': False, 'percentOfDailyNeeds': 27.84}, {'title': 'Fat', 'amount': '29g', 'indented': False, 'percentOfDailyNeeds': 44.62}, {'title': 'Saturated Fat', 'amount': '4g', 'indented': True, 'percentOfDailyNeeds': 25.37}, {'title': 'Carbohydrates', 'amount': '65g', 'indented': False, 'percentOfDailyNeeds': 21.68}, {'title': 'Sugar', 'amount': '5g', 'indented': True, 'percentOfDailyNeeds': 5.98}, {'title': 'Cholesterol', 'amount': '0.0mg', 'indented': False, 'percentOfDailyNeeds': 0.0}, {'title': 'Sodium', 'amount': '649mg', 'indented': False, 'percentOfDailyNeeds': 28.25}]
# Name: badNutrition, dtype: object

# %%
import json
def json_to_series(text):
    keys, values = zip(*[item for dct in json.loads(text) for item in dct.items()])
    return pd.Series(values, index=keys)

# %%
result = pd.concat([nutrition, nutrition['goodNutrition'].apply(json_to_series)], axis=1)
result
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-44-495d9fe51ee2> in <module>
# ----> 1 result = pd.concat([nutrition, nutrition['goodNutrition'].apply(json_to_series)], axis=1)
#       2 result
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    4136             else:
#    4137                 values = self.astype(object)._values
# -> 4138                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4139
#    4140         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-43-1c2cd0302bab> in json_to_series(text)
#       1 import json
#       2 def json_to_series(text):
# ----> 3     keys, values = zip(*[item for dct in json.loads(text) for item in dct.items()])
#       4     return pd.Series(values, index=keys)
#
# ~\Anaconda3\lib\json\__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     355             parse_int is None and parse_float is None and
#     356             parse_constant is None and object_pairs_hook is None and not kw):
# --> 357         return _default_decoder.decode(s)
#     358     if cls is None:
#     359         cls = JSONDecoder
#
# ~\Anaconda3\lib\json\decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# ~\Anaconda3\lib\json\decoder.py in raw_decode(self, s, idx)
#     351         """
#     352         try:
# --> 353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
#     355             raise JSONDecodeError("Expecting value", s, err.value) from None
#
# JSONDecodeError: Expecting property name enclosed in double quotes: line 1 column 3 (char 2)

# %%
nutrition_flattened = pd.DataFrame.from_dict(nutrition['goodNutrition'])
#nutrition_flattened = nutrition_flattened.apply(pd.Series)
#.replace("[","").replace("]","")
nutrition_flattened
# Out:
#                                          goodNutrition
# 0    [{'title': 'Protein', 'amount': '35g', 'indent...
# 1    [{'title': 'Protein', 'amount': '39g', 'indent...
# 2    [{'title': 'Protein', 'amount': '29g', 'indent...
# 3    [{'title': 'Protein', 'amount': '5g', 'indente...
# 4    [{'title': 'Protein', 'amount': '13g', 'indent...
# ..                                                 ...
# 495  [{'title': 'Protein', 'amount': '8g', 'indente...
# 496  [{'title': 'Protein', 'amount': '18g', 'indent...
# 497  [{'title': 'Protein', 'amount': '27g', 'indent...
# 498  [{'title': 'Protein', 'amount': '37g', 'indent...
# 499  [{'title': 'Protein', 'amount': '35g', 'indent...
#
# [11045 rows x 1 columns]

# %%
nutrition['goodNutrition'].apply(pd.Series)
# Out:
#                                                      0
# 0    [{'title': 'Protein', 'amount': '35g', 'indent...
# 1    [{'title': 'Protein', 'amount': '39g', 'indent...
# 2    [{'title': 'Protein', 'amount': '29g', 'indent...
# 3    [{'title': 'Protein', 'amount': '5g', 'indente...
# 4    [{'title': 'Protein', 'amount': '13g', 'indent...
# ..                                                 ...
# 495  [{'title': 'Protein', 'amount': '8g', 'indente...
# 496  [{'title': 'Protein', 'amount': '18g', 'indent...
# 497  [{'title': 'Protein', 'amount': '27g', 'indent...
# 498  [{'title': 'Protein', 'amount': '37g', 'indent...
# 499  [{'title': 'Protein', 'amount': '35g', 'indent...
#
# [11045 rows x 1 columns]

# %%
#flavor_pivoted_byCuisine = pd.melt(taste, id_vars=['cuisine'], value_vars=['sweetness', 'saltiness','sourness','bitterness','savoriness','fattiness', 'spiciness'])
# Melt with 'cuisine' as key
import numpy as np

nutrition = pd.concat([nutrition.drop(['goodNutrition'], axis=1), nutrition['goodNutrition'].apply(pd.Series)], axis=1)
nutrition
# Out:
#                                           badNutrition      id  \
# 0    [{'title': 'Calories', 'amount': '720k', 'inde...  314135
# 1    [{'title': 'Calories', 'amount': '487k', 'inde...  715038
# 2    [{'title': 'Calories', 'amount': '752k', 'inde...  653275
# 3    [{'title': 'Calories', 'amount': '168k', 'inde...   47119
# 4    [{'title': 'Calories', 'amount': '375k', 'inde...  122714
# ..                                                 ...     ...
# 495  [{'title': 'Calories', 'amount': '349k', 'inde...  520285
# 496  [{'title': 'Calories', 'amount': '422k', 'inde...  611974
# 497  [{'title': 'Calories', 'amount': '1112k', 'ind...  755718
# 498  [{'title': 'Calories', 'amount': '482k', 'inde...  201020
# 499  [{'title': 'Calories', 'amount': '485k', 'inde...  577571
#
#                                                  title     cuisine  \
# 0      North African Inspired Rub for Fish and Chicken     African
# 1    Harissa Shakshuka (North African Eggs in Purga...     African
# 2                          North African Chickpea Soup     African
# 3                             South African Beef Curry     African
# 4                    West African Tropical Fruit Salad     African
# ..                                                 ...         ...
# 495                          Fresh Shrimp Spring Rolls  Vietnamese
# 496                 Quick Banh Mi {street food monday}  Vietnamese
# 497                     Vietnamese Grilled Squid Salad  Vietnamese
# 498                                  Breakfast Banh Mi  Vietnamese
# 499                              {spring} spring rolls  Vietnamese
#
#                                                      0
# 0    [{'title': 'Protein', 'amount': '35g', 'indent...
# 1    [{'title': 'Protein', 'amount': '39g', 'indent...
# 2    [{'title': 'Protein', 'amount': '29g', 'indent...
# 3    [{'title': 'Protein', 'amount': '5g', 'indente...
# 4    [{'title': 'Protein', 'amount': '13g', 'indent...
# ..                                                 ...
# 495  [{'title': 'Protein', 'amount': '8g', 'indente...
# 496  [{'title': 'Protein', 'amount': '18g', 'indent...
# 497  [{'title': 'Protein', 'amount': '27g', 'indent...
# 498  [{'title': 'Protein', 'amount': '37g', 'indent...
# 499  [{'title': 'Protein', 'amount': '35g', 'indent...
#
# [11045 rows x 5 columns]

# %%
nutrition = pd.concat([nutrition.drop(['0'], axis=1), nutrition['0'].apply(pd.Series)], axis=1)
nutrition
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-ca3963acb098> in <module>
# ----> 1 nutrition = pd.concat([nutrition.drop(['0'], axis=1), nutrition['0'].apply(pd.Series)], axis=1)
#       2 nutrition
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4154
#    4155         if inplace:
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    4186                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4187             else:
# -> 4188                 new_axis = axis.drop(labels, errors=errors)
#    4189             result = self.reindex(**{axis_name: new_axis})
#    4190
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    5589         if mask.any():
#    5590             if errors != "ignore":
# -> 5591                 raise KeyError(f"{labels[mask]} not found in axis")
#    5592             indexer = indexer[~mask]
#    5593         return self.delete(indexer)
#
# KeyError: "['0'] not found in axis"

# %%
flavor_grouped_byCuisine
# Out:
#              cuisine  sweetness  saltiness   sourness  bitterness  savoriness  \
# 0            African  62.137824  67.217353  34.865824   28.495176   38.197941
# 1           American  59.044920  72.916520  41.882140   30.361040   43.979340
# 2            British  66.256100  44.988180  23.402340   17.131300   23.229080
# 3              Cajun  46.537140  77.776140  34.270740   26.874960   46.474800
# 4          Caribbean  62.250940  60.223000  25.631920   22.126660   39.433700
# 5            Chinese  46.824080  86.889420  26.197580   33.452680   53.504020
# 6   Eastern European  39.229620  95.212700  32.917500   29.876300   58.345860
# 7           European  54.305180  78.691680  46.642340   36.208560   45.267140
# 8             French  44.684660  88.074600  34.860460   31.167400   44.656160
# 9             German  49.035120  72.032500  22.098900   20.779260   38.950700
# 10            Indian  62.871180  67.239780  41.455440   34.461700   35.570620
# 11             Irish  35.681840  92.780940  21.907480   28.064120   39.887040
# 12           Italian  55.753760  79.044080  48.017880   36.156300   47.009520
# 13            Jewish  38.802040  93.031500  30.170580   24.614180   49.141660
# 14            Korean  49.028420  86.995740  24.287820   28.507500   50.211720
# 15    Latin American  34.979940  66.979120  34.136520   24.233880   37.621360
# 16     Mediterranean  55.486860  79.024060  48.320100   37.511840   46.487300
# 17    Middle Eastern  43.213820  44.421440  55.122260   42.705100   22.068800
# 18            Nordic  57.222400  69.799387  20.554400   19.011973   40.346293
# 19          Southern  53.609220  64.440920  28.332220   24.586200   38.398820
# 20           Spanish  48.523560  79.022320  42.518080   29.943500   46.204160
# 21              Thai  57.836600  75.332000  28.381580   31.997240   49.131120
# 22        Vietnamese  57.529820  75.731260  25.563780   34.672080   49.847620
#
#     fattiness     spiciness
# 0    66.10300  5.527374e+05
# 1    67.00252  1.446679e+06
# 2    74.42786  6.065368e+04
# 3    68.57418  2.792083e+05
# 4    60.23418  6.899148e+05
# 5    66.59982  8.045560e+05
# 6    63.77872  1.999277e+05
# 7    68.12250  1.050325e+05
# 8    70.55514  1.559065e+05
# 9    66.35832  2.003863e+05
# 10   64.54452  1.105403e+06
# 11   63.28130  1.771711e+05
# 12   69.04536  8.027951e+04
# 13   58.63148  6.026084e+05
# 14   61.87504  4.648000e+05
# 15   76.56506  4.734989e+05
# 16   68.17056  1.152339e+05
# 17   80.43878  1.097556e+05
# 18   66.60480  1.224662e+05
# 19   73.46270  6.496670e+05
# 20   70.90368  4.204405e+05
# 21   70.16374  8.915695e+05
# 22   62.05442  9.087713e+05

# %%
## Create bar chart with flavor profiling
## NEED TO UPDATE TO DYNAMICALLY SPIT OUT MULTIPLE CHARTS
input_dropdown_cuisine = alt.binding_select(options=taste.cuisine.unique(), name='Cuisines')
selection = alt.selection_multi(fields=['cuisine'], empty='none')

alt.data_transformers.enable('default', max_rows=None)

color = alt.condition(selection, alt.Color('cuisine:N', legend=None), alt.value('lightgray'))
make_selector = alt.Chart(flavor_grouped_byCuisine).mark_rect().encode(y='cuisine', color=color).add_selection(selection)

# Layering and configuring the components
chart_sweet = alt.Chart(flavor_grouped_byCuisine).mark_bar(
    ).encode(
        x=alt.X('sweetness:Q'),
    y = 'cuisine',
    color = color
    ).properties(width=300, height=300, title='Sweetness'
).transform_filter(
    selection
)

chart_spicy = alt.Chart(flavor_grouped_byCuisine).mark_bar(
    ).encode(
        x=alt.X('spiciness:Q'),
    y = 'cuisine',
    color = color
    ).properties(width=300, height=300, title='Spiciness'
).transform_filter(
    selection
)
    
chart_salty = alt.Chart(flavor_grouped_byCuisine).mark_bar(
    ).encode(
        x=alt.X('saltiness:Q'),
    y = 'cuisine',
    color = color
    ).properties(width=300, height=300, title='Saltiness'
).transform_filter(
    selection
)

chart_sour = alt.Chart(flavor_grouped_byCuisine).mark_bar(
    ).encode(
        x=alt.X('sourness:Q'),
    y = 'cuisine',
    color = color
    ).properties(width=300, height=300, title='Sourness'
).transform_filter(
    selection
)

chart_bitter = alt.Chart(flavor_grouped_byCuisine).mark_bar(
    ).encode(
        x=alt.X('bitterness:Q'),
    y = 'cuisine',
    color = color
    ).properties(width=300, height=300, title='Bitterness'
).transform_filter(
    selection
)

chart_savory = alt.Chart(flavor_grouped_byCuisine).mark_bar(
    ).encode(
        x=alt.X('savoriness:Q'),
    y = 'cuisine',
    color = color
    ).properties(width=300, height=300, title='Savoriness'
).transform_filter(
    selection
)

chart_fatty = alt.Chart(flavor_grouped_byCuisine).mark_bar(
    ).encode(
        x=alt.X('fattiness:Q'),
    y = 'cuisine',
    color = color
    ).properties(width=300, height=300, title='Fattiness'
).transform_filter(
    selection
)

print("Hold down SHIFT and click on the boxes next to two or more cuisines to see how their average flavor profiles compare:")
alt.vconcat(make_selector, chart_sweet | chart_spicy | chart_fatty, chart_salty | chart_sour | chart_bitter | chart_savory)
# Out:
# Hold down SHIFT and click on the boxes next to two or more cuisines to see how their average flavor profiles compare:
# alt.VConcatChart(...)
